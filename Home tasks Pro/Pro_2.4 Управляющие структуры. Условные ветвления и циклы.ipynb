# %% [markdown]
# # Курс "Python для анализа данных"
#
# ---
# # Домашнее задание PRO
# #2.4 Управляющие структуры. Условные ветвления и циклы

# %%
# Запустите код ниже для старта, но не правьте во избежании ошибок проверки!
_HOMEWORK_NAME_ = '2.4_PRO'
_HOMEWORK_ANSWER_DICT_ = dict()

# %% [markdown]
# ## ФИО участника

# %%
# Введите ваше имя и фамилию в соответствующую позицию 'NAME' и 'LAST_NAME'!
# Пример: Иван Иванов - 'NAME' : 'Иван', 'LAST_NAME' : 'Иванов'
_NAME_SERNAME_ = {
    'NAME' : 'ILIA',
    'LAST_NAME' : 'KONUSHOK'
}

# %% [markdown]
# ## Задание 1

# %% [markdown]
# Вычислить приблизительное значение экспоненциальной функции с использованием ряда Тейлора:
# $$
# e^x=\sum_{n=0}^{100} {\frac {x^n} {n!}}.
# $$
# Найдите значение $e^{20}$, округленное до 5 знаков после запятой.
#
# **Формат ответа:**
# Число (например, ```3213156.11234```)
#
# **Оценка в баллах:** 3

# %% [markdown]
# **Решение:**

# %%
import math

sum_e = 0
x = 20

for n in range(100):  
  sum_e += pow(x,n) / math.factorial(n)
  
print (round(sum_e,5))
# Out:
# 485165195.40979

# %% [markdown]
# **Ответ:**

# %%
# Не изменяйте текст до знака = во избежании ошибок проверки!
_HOMEWORK_ANSWER_DICT_['A1'] = '485165195.40979'

# %% [markdown]
# ## Задание 2

# %% [markdown]
# **Условие:**
# Найдите среднее арифметическое всех **простых** делителей числа $n$, заданного пользователем. Дайте ответ для $n = 125632$. Требуется сперва получить лист делителей, а потом уже найти среднее арифметическое.
#
# **Формат ответа:** Число (например, ```2112.87```)
#
# **Оценка в баллах:** 3

# %% [markdown]
# **Решение:**

# %%
n = int(input("n="))

sum_lst = 0
lst=[]
for i in range(2, n+1):  
  for j in lst:     # пробегаем по списку (lst) простых чисел
    if i % j == 0:
      break
  else:
    if n % i == 0:    # Если число является простым делителем n - записываем в lst
      lst.append(i)

print (lst, sum(lst) / len(lst))
# Out:
# n=125632
# [2, 13, 151] 55.333333333333336

# %% [markdown]
# **Ответ:**

# %%
# Не изменяйте текст до знака = во избежании ошибок проверки!
_HOMEWORK_ANSWER_DICT_['A2'] = 55.333333333333336

# %% [markdown]
# ## Задание 3

# %% [markdown]
# **Условие:** Создайте игру, в которой пользователь должен угадать заранее случайным образом выбранное целое число от 1 до 100. В случае неправильного ответа программа должна делать подсказки вида: это число меньше(больше), чем загаданное.  Используйте модуль ```random``` и цикл ```while```. Не забудьте поставить условие выхода, например, при вводе символа *. Сыграйте с машиной в эту игру 3 раза(в каждой игре до выигрыша) и укажите среднее значение попыток до успешного угадывания.
#
# **Формат ответа:** Число (например, ```8```)
#
# **Оценка в баллах:** 4

# %% [markdown]
# **Решение:**

# %%
import random

def igra (n):   # делаем игру в виде функции
  n = random.randrange(1, 100, 1) 
  x = 0
  while x != n:
    a = input("Введите число от 1 до 100 или * для прерывания :  ")
    if a == "*": break
    else: 
      x = int(a)
      if x == n: 
        print ("Угадали!")
      elif x > n: print ("Мое число меньше")
      else: print ("Мое число больше")

for i in range(3):    # играем 3 раза
  igra (i)
# Out:
# Введите число от 1 до 100 или * для прерывания :  50
# Мое число меньше
# Введите число от 1 до 100 или * для прерывания :  25
# Мое число меньше
# Введите число от 1 до 100 или * для прерывания :  12
# Мое число больше
# Введите число от 1 до 100 или * для прерывания :  19
# Мое число больше
# Введите число от 1 до 100 или * для прерывания :  22
# Мое число меньше
# Введите число от 1 до 100 или * для прерывания :  20
# Угадали!
# Введите число от 1 до 100 или * для прерывания :  50
# Мое число меньше
# Введите число от 1 до 100 или * для прерывания :  25
# Мое число меньше
# Введите число от 1 до 100 или * для прерывания :  12
# Угадали!
# Введите число от 1 до 100 или * для прерывания :  50
# Мое число больше
# Введите число от 1 до 100 или * для прерывания :  75
# Мое число меньше
# Введите число от 1 до 100 или * для прерывания :  63
# Мое число меньше
# Введите число от 1 до 100 или * для прерывания :  57
# Мое число больше
# Введите число от 1 до 100 или * для прерывания :  60
# Мое число больше
# Введите число от 1 до 100 или * для прерывания :  62
# Угадали!

# %% [markdown]
# **Ответ:**

# %%
# Не изменяйте текст до знака = во избежании ошибок проверки!
_HOMEWORK_ANSWER_DICT_['A3'] = '5'

# %% [markdown]
# ## Комментарии участника

# %%
_YOUR_COMMENT_ = 'All right!'

# %% [markdown]
# ## Создание отчета

# %%
# Проверьте правильность заполнения полей выше и 
# выполните данный код для создания отчета
# и сохранения его на локальную машину
from google.colab import files
import json
try:
  # form a report
  _HM_REPORT_ = {'Answers':_HOMEWORK_ANSWER_DICT_,
                'Comment':_YOUR_COMMENT_,
                'User':_NAME_SERNAME_,
                }

  # create a report name
  _REPORT_NAME_ = 'HM_' +\
                    _HOMEWORK_NAME_ + \
                  '_by_' + \
                  _NAME_SERNAME_['LAST_NAME'] + \
                  '.json'
  
  # Save a report to a file
  f = open(_REPORT_NAME_,"w")
  f.write(json.dumps(_HM_REPORT_))
  f.close()

  # Donwnload the file into a local host
  files.download(_REPORT_NAME_) 
  print('Thanks for the work, {name}!'.format(name=_NAME_SERNAME_['NAME']))
except Exception as error:
   print(error)
   print('Something went wrong! Check the data entry and try again!')
# Out:
# Thanks for the work, ILIA!
