# %% [markdown]
# # Курс "Python для анализа данных"
#
# ---
# # Домашнее задание PRO
# #2.8.2 Создание собственных классов

# %%
# Запустите код ниже для старта, но не правьте во избежании ошибок проверки!
_HOMEWORK_NAME_ = '2.8.2_PRO'
_HOMEWORK_ANSWER_DICT_ = dict()

# %% [markdown]
# ## ФИО участника

# %%
# Введите ваше имя и фамилию в соответствующую позицию 'NAME' и 'LAST_NAME'!
# Пример: Иван Иванов - 'NAME' : 'Иван', 'LAST_NAME' : 'Иванов'
_NAME_SERNAME_ = {
    'NAME' : 'ILIA',
    'LAST_NAME' : 'KONUSHOK'
}

# %% [markdown]
# ## Задание 1

# %% [markdown]
# **Условие:** Создайте собственный класс ```Person``` работника компании. Добавьте следующие атрибуты данных, использую конструктор ```__init__```:
#
# *   ```name```(фамилия)
# *   ```job```(должность)
# *   ```pai```(зарплата)
#
# Создайте метод класса ```person_raise(self, prcnt)```, который повышает зарплату на ```prcnt``` процентов от имеющегося значения. Создайте работника и выведите кортеж с 2мя значениями: (зарплата при создании работника, зарплата после повышения на 20%)
#
# **Формат ответа:** кортеж (например, ```(150, 200)```)
#
# **Оценка в баллах:** 3

# %% [markdown]
# **Решение:**

# %%
# Создаем класс сотрудников
class Person:
  # создаем атрибуты класса
  def __init__(self):
    self.name = 'Фамилия'
    self.job = 'Должность'
    self.pai = 'Зарплата'

  # создание методов класса
  def person_raise(self, prcnt):
    vedomost = (int(pers1.pai), int(float(pers1.pai)*(1+prcnt)))
    print ('Ответ: ', vedomost)
    pers1.pai = int(float(pers1.pai)*(1+prcnt)) # повышаем зарплату pers1


# Создаем конкретный экземпляр класса
pers1 = Person()
pers1.name = input ('Введите фамилию: ')
pers1.job = input ('Введите должность: ')
pers1.pai = input ('Введите зарплату: ')
print(pers1.name, pers1.job, pers1.pai)

# Применяем метод  - индексируем зарплату 
prcnt = 0.2
pers1.person_raise(prcnt)
# Out:
# Введите фамилию: Иванов
# Введите должность: програмимст
# Введите зарплату: 100
# Иванов програмимст 100
# Ответ:  (100, 120)

# %% [markdown]
# **Ответ:**

# %%
# Не изменяйте текст до знака = во избежании ошибок проверки!
_HOMEWORK_ANSWER_DICT_['A1'] = (100, 120)

# %% [markdown]
# ## Задание 2

# %% [markdown]
# **Условие:** Создайте класс ```Manager``` наследника класса ```Person```, который имеет дополнительный атрибут данных ```client_counts```(количество клиентов). В классе ```Manager``` создайте метод ```manager_raise()```, который
# увеличивает количество клиентов менеджера на 1 и зарплату менеджера на 1%. Выведите кортеж с 2мя значениями: (зарплата менеджера при создании, зарплата после добавления 10 клиентов). Замечание: зарплата менеджера должна быть повышена с использованием методов наследуемого класса.
#
# **Формат ответа:** кортеж (например, ```(150, 170)```)
#
# **Оценка в баллах:** 3

# %% [markdown]
# **Решение:**

# %%
class Manager(Person):
  # добавляем атрибут класса
  def __init__(self):
    self.client_counts = 'Количество клиентов'
  
  # создание метода класса
  def manager_raise(self, clients_number, per_clent_index):
    vedomost_2 = (int(pers1.pai), int(float(pers1.pai) * ( 1 + clients_number*per_clent_index)))
    print ('Ответ: ', vedomost_2)
    manager1.pai = int(float(pers1.pai) * ( 1 + clients_number*per_clent_index)) # повышаем зарплату pers1
    manager1.job = 'менеджер'
    manager1.name = pers1.name
    print('Повышение: ', manager1.name, manager1.job, manager1.pai)
    pers1.name = 'Wanted'
    print('Обьявляем вакансию: ', pers1.name, pers1.job, pers1.pai)
  
print('Будущий менеджер: ', pers1.name, pers1.job, pers1.pai)

# Применяем метод  - индексируем зарплату
manager1 = Manager()
clients_number = int(input('Сколько клиентов ему добавим?: '))
per_clent_index = 0.01
manager1.manager_raise(clients_number, per_clent_index)
# Out:
# Будущий менеджер:  Иванов програмимст 120
# Сколько клиентов ему добавим?: 10
# Ответ:  (120, 132)
# Повышение:  Иванов менеджер 132
# Обьявляем вакансию:  Wanted програмимст 120

# %% [markdown]
# **Ответ:**

# %%
# Не изменяйте текст до знака = во избежании ошибок проверки!
_HOMEWORK_ANSWER_DICT_['A2'] = (120, 132)

# %% [markdown]
# ## Задание 3

# %% [markdown]
# **Условие:** Используя конструктор, создайте класс ```Department``` с атрибутами данных:
#
# *   ```name```(название департамента)
# *   ```chief```(начальник - объект класса ```Person```)
# *   ```person_list```(список подчиненных - объектов классов ```Person``` и ```Manager```)
#
# Создайте департамент с ```5``` менеджерами и ```5``` разнорабочими. Создайте метод класса ```xristmas_tree()```, который выберает ```3``` случайных сотрудников (можно/нужно начальника) и повышает им зарплату на ```30%```. Запустите этот метод ```20``` раз и выведите количество поощренных сотрудников(поощренный - получил надбавку хотя бы один раз).
#
# **Формат ответа:** число(например, 3)
#
# **Оценка в баллах:** 4

# %% [markdown]
# **Решение:**

# %%
# Создание конструкторов и деструкторов
class Department(Manager):
  # создаем атрибуты класса
  def __init__(self, name_dept, chief, person_list):
    self.name_dept = 'Название департамента'
    self.chief = 'Начальник'
    self.person_list = 'Список подчиненных'

# Создаем департамент
dept1 = Department('АСУ', 'Петров', '')   # не понимаю, почему не присваиваются и не выводятся значения
print (dept1.name_dept, dept1.chief, dept1.person_list)
# Создаем список сотрудников
person_list = [pers1, manager1]     # не понимаю, почему не присваиваются и не выводятся значения
print(pers1.name, pers1.job, pers1.pai)
print(person_list[0])           # не понимаю, почему не присваиваются и не выводятся значения


# попытка сделать все вручную тоже не удалась
employer0 = Manager()  # начальник
employer1 = Manager()
employer2 = Manager()
employer3 = Manager()
employer4 = Manager()
employer5 = Manager()

employer0.person_list = ['Петров', 'Начальник', '300']
employer1.person_list = ['Иванов', 'Менеджер', '132']
employer2.person_list = ['Иванов', 'Менеджер', '120']
employer3.person_list = ['Иванов', 'Менеджер', '110']
employer4.person_list = ['Иванов', 'Менеджер', '115']
employer5.person_list = ['Иванов', 'Менеджер', '150']
# Out:
# Название департамента Начальник Список подчиненных
# Wanted програмимст 120
# ...

# %% [markdown]
# **Ответ:**

# %%
# Не изменяйте текст до знака = во избежании ошибок проверки!
_HOMEWORK_ANSWER_DICT_['A3'] = 'Your answer3'

# %% [markdown]
# ## Комментарии участника

# %%
_YOUR_COMMENT_ = 'Прошу подсказать с третьим заданием - уже второй день бьюсь )'

# %% [markdown]
# ## Создание отчета

# %%
# Проверьте правильность заполнения полей выше и 
# выполните данный код для создания отчета
# и сохранения его на локальную машину
from google.colab import files
import json
try:
  # form a report
  _HM_REPORT_ = {'Answers':_HOMEWORK_ANSWER_DICT_,
                'Comment':_YOUR_COMMENT_,
                'User':_NAME_SERNAME_,
                }

  # create a report name
  _REPORT_NAME_ = 'HM_' +\
                    _HOMEWORK_NAME_ + \
                  '_by_' + \
                  _NAME_SERNAME_['LAST_NAME'] + \
                  '.json'
  
  # Save a report to a file
  f = open(_REPORT_NAME_,"w")
  f.write(json.dumps(_HM_REPORT_))
  f.close()

  # Donwnload the file into a local host
  files.download(_REPORT_NAME_) 
  print('Thanks for the work, {name}!'.format(name=_NAME_SERNAME_['NAME']))
except Exception as error:
   print(error)
   print('Something went wrong! Check the data entry and try again!')
# Out:
# Thanks for the work, ILIA!
